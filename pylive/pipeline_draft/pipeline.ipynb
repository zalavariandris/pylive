# %%
import image_utils as utils
from pipeline_v01 import Pipeline, execute

import rich
from pathlib import Path
rich.print(f"""
[bold cyan]Pipeline v0.1[/bold cyan]
    cwd: {Path.cwd()!r}""")


# model
base_pipeline = Pipeline(
    utils.read_image,
    path="../../assets/IMG_0885.JPG")\
.append(
    utils.reformat,
    size=(512, 512))\
.append(
    utils.merge_over,
    B=Pipeline(
        utils.checkerboard, size=(512,512), square_size=8
    ),
    mix=0.5)

# import ipywidgets as widgets
# from IPython.display import display
import matplotlib.pyplot as plt

plt.imshow(execute(base_pipeline))
plt.axis('off')
# Out:
# Pipeline v0.1
#     cwd: WindowsPath('c:/Users/and/Documents/GitHub/pylive/pylive/pipeline_draft')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 29
#      25 # import ipywidgets as widgets
#      26 # from IPython.display import display
#      27 import matplotlib.pyplot as plt
# ---> 29 plt.imshow(execute(base_pipeline))
#      30 plt.axis('off')
#
# File c:\Users\and\Documents\GitHub\pylive\pylive\pipeline_draft\pipeline_v01.py:55, in execute(pipeline, *args, **kwargs)
#      52         kwargs_evaluated[key] = value
#      54     # print(f"Executing: {func.__name__} with args={args_evaluated} kwargs={kwargs_evaluated}")
# ---> 55     current_value = func(*args_evaluated, **kwargs_evaluated)
#      56 return current_value
#
# TypeError: merge_over() got an unexpected keyword argument 'mix'
